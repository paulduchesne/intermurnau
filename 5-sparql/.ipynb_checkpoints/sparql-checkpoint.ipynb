# %% [markdown]
# # Murnau SPARQL examples.

# %%
# querying function.

import requests, pydash, pandas
import altair, numpy

def run_query(search, url):
    
    def value_extract(row, col):
        return pydash.get(row[col], 'value')    
    
    r = requests.get(url, params = {'format': 'json', 'query': search})
    data = pydash.get(r.json(), 'results.bindings')
    data = pandas.DataFrame.from_dict(data)

    for x in data.columns:    
        data[x] = data.apply(value_extract, col=x, axis=1)
        
    return data

# %% [markdown]
# ##### SPARQL #1: Works, with contributors work ids.

# %%
dataframe = run_query("""
    SELECT DISTINCT ?work ?workLabel ?aca_id ?bfi_id ?eye_id ?gfa_id ?loc_id ?mom_id ?nfa_id ?sfi_id
    WHERE
    {
        # ?work wdt:P1 wd:Q1019.
        OPTIONAL { ?work p:P29 [ps:P29 ?aca_id;  pq:P33 wd:Q160 ]}.
        OPTIONAL { ?work p:P29 [ps:P29 ?bfi_id;  pq:P33 wd:Q897 ]}.        
        OPTIONAL { ?work p:P29 [ps:P29 ?eye_id;  pq:P33 wd:Q530 ]}.
        OPTIONAL { ?work p:P29 [ps:P29 ?gfa_id;  pq:P33 wd:Q820 ]}. 
        OPTIONAL { ?work p:P29 [ps:P29 ?loc_id;  pq:P33 wd:Q402 ]}.
        OPTIONAL { ?work p:P29 [ps:P29 ?mom_id;  pq:P33 wd:Q978 ]}.        
        OPTIONAL { ?work p:P29 [ps:P29 ?nfa_id;  pq:P33 wd:Q959 ]}.
        OPTIONAL { ?work p:P29 [ps:P29 ?sfi_id;  pq:P33 wd:Q15 ]}.         
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

dataframe = dataframe.pivot_table(index=['work', 'workLabel'], aggfunc=lambda x: ', '.join(sorted(x.unique().astype(str)))).reset_index()

print(len(dataframe))
dataframe.head(25)
# Out:
# 21
#                                work  \
# 0   http://wikibase.svc/entity/Q100
# 1   http://wikibase.svc/entity/Q124
# 2    http://wikibase.svc/entity/Q13
# 3    http://wikibase.svc/entity/Q14
# 4   http://wikibase.svc/entity/Q145
# 5   http://wikibase.svc/entity/Q175
# 6   http://wikibase.svc/entity/Q185
# 7   http://wikibase.svc/entity/Q187
# 8    http://wikibase.svc/entity/Q19
# 9   http://wikibase.svc/entity/Q202
# 10  http://wikibase.svc/entity/Q215
# 11  http://wikibase.svc/entity/Q217
# 12   http://wikibase.svc/entity/Q23
# 13  http://wikibase.svc/entity/Q356
# 14   http://wikibase.svc/entity/Q36
# 15  http://wikibase.svc/entity/Q378
# 16   http://wikibase.svc/entity/Q41
# 17   http://wikibase.svc/entity/Q43
# 18  http://wikibase.svc/entity/Q448
# 19   http://wikibase.svc/entity/Q55
# 20   http://wikibase.svc/entity/Q77
#
#                                             workLabel    aca_id  bfi_id  \
# 0                                                Tabu   W068911   47225
# 1                                            4 Devils   W081960   30079
# 2                                             Phantom      None   22035
# 3                                             Tartüff  W1253260   47423
# 4                                             Sunrise   W061911   46936
# 5                                 Der brennende Acker   W074412  132871
# 6                       Die Finanzen des Grossherzogs      None   54847
# 7             MARIZZA, GENANNT DIE SCHMUGGLER-MADONNA      None  227671
# 8   SCHLOß VOGELOED: DIE ENTHÜLLUNG EINES GEHEIMNI...   W093767  277824
# 9                                           SEHNSUCHT      None  280286
# 10                                              Faust   W079529   29301
# 11                                            SATANAS      None  276788
# 12                                          City Girl   W094098  144495
# 13                                      Der JANUSKOPF      None  206458
# 14        Die AUSTREIBUNG  DIE MACHT DER ZWEITEN FRAU      None   25287
# 15                              Der Gang in die Nacht      None   55082
# 16                                    Der letzte Mann   W068878  332971
# 17                                  Der KNABE IN BLAU      None  212013
# 18                                 ABEND-NACHT-MORGEN      None  591513
# 19                      Der BUCKLIGE UND DIE TÄNZERIN      None  134375
# 20                                          Nosferatu   W062017  244786
#
#       eye_id gfa_id          loc_id mom_id   nfa_id  sfi_id
# 0   FLM65135  77258            1675  W2770  0201933   31600
# 1       None   None           49552   None     None   26009
# 2   FLM52517  75320            None   W254  2200092   30184
# 3   FLM27886   1210            None  W2778  2200594    9256
# 4   FLM64568   None         1162650  W2748  0200811   17859
# 5       None  53080            None   None  2200145   30183
# 6       None  58485            None   None  2200095   25850
# 7       None   None            None   None     None   50369
# 8       None  74618            None   None  2200713   52981
# 9       None   None            None   None     None   30187
# 10  FLM20376   5431         1208391  W7265  2200093    9190
# 11      None   None            None   None     None    None
# 12  FLM12186   None            None   W986  0200640   19678
# 13      None   None            None   None     None   27500
# 14      None   None            None   None     None   30185
# 15      None  61578            None   None  2200043   91955
# 16  FLM38127   5438  211163, 827960  W2043  2200560    9215
# 17      None   None            None   None     None   30186
# 18      None   None            None   None     None    None
# 19      None   None            None   None     None  625469
# 20  FLM47528  40041           65023  W1558  2200610   11806

# %% [markdown]
# ##### SPARQL #2: Lost works, as far as can be ascertained from contributed data.

# %%
dataframe = run_query("""
    SELECT DISTINCT ?work ?workLabel ?item
    WHERE
    {
        # ?work wdt:P1 wd:Q1019.
        OPTIONAL {?work wdt:P12 ?manifestation. 
        OPTIONAL {?manifestation wdt:P14 ?item}}.
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

dataframe = dataframe.pivot_table(index=['work', 'workLabel'], aggfunc=lambda x: ', '.join(sorted(x.unique().astype(str)))).reset_index()
dataframe = dataframe.loc[dataframe.item.isin(['None'])]

print(len(dataframe))
dataframe.head(20)
# Out:
# 8
#                                work  \
# 7   http://wikibase.svc/entity/Q187
# 9   http://wikibase.svc/entity/Q202
# 11  http://wikibase.svc/entity/Q217
# 13  http://wikibase.svc/entity/Q356
# 14   http://wikibase.svc/entity/Q36
# 17   http://wikibase.svc/entity/Q43
# 18  http://wikibase.svc/entity/Q448
# 19   http://wikibase.svc/entity/Q55
#
#                                       workLabel  item
# 7       MARIZZA, GENANNT DIE SCHMUGGLER-MADONNA  None
# 9                                     SEHNSUCHT  None
# 11                                      SATANAS  None
# 13                                Der JANUSKOPF  None
# 14  Die AUSTREIBUNG  DIE MACHT DER ZWEITEN FRAU  None
# 17                            Der KNABE IN BLAU  None
# 18                           ABEND-NACHT-MORGEN  None
# 19                Der BUCKLIGE UND DIE TÄNZERIN  None

# %% [markdown]
# ##### SPARQL #3: Murnau works forbidden in Sweden.

# %%
dataframe = run_query("""
    SELECT DISTINCT ?work ?workLabel
    WHERE
    {
        # ?work p:P8 ?event.
        # ?event pq:P35 "Totalförbjuden". 
        # ?event pq:P36 wd:Q955. 
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

print(len(dataframe))
dataframe.head()
# Out:
# 2
#                              work                      workLabel
# 0  http://wikibase.svc/entity/Q55  Der BUCKLIGE UND DIE TÄNZERIN
# 1  http://wikibase.svc/entity/Q77                      Nosferatu

# %% [markdown]
# ##### SPARQL #4: Murnau agents' birthdates contributed by the EYE, against BFI authority ids.

# %%
dataframe = run_query("""
    SELECT ?agentLabel ?birth ?bfi_id
    WHERE
    {
        # ?agent wdt:P1 wd:Q1017;
        p:P8 [ps:P8 ?birth;  pq:P31 wd:Q945 ];
        p:P29 [ps:P29 ?bfi_id;  pq:P33 wd:Q897 ]
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

print(len(dataframe))
dataframe.head(40)
# Out:
# 30
#          birth                    agentLabel  bfi_id
# 0   1885-09-25                   Hanna Ralph  179412
# 1         1899                  Floyd Crosby  219024
# 2         1893             Alexander Granach  181219
# 3   1884-06-23                 Werner Krauss  170749
# 4   1883-12-27                  Eddie Boland  306298
# 5   1881-01-07                 Henrik Galeen  181302
# 6         1894                    Carl Mayer  225540
# 7   1889-07-20                  Erich Pommer  184808
# 8         1851                Guido Herzfeld  338777
# 9   1900-04-19                George O'Brien  171200
# 10  1892-08-18                Bill Bambridge  854396
# 11  1882-11-07                  Hans Erdmann  407740
# 12  1876-01-25                  Rosa Valetti  181633
# 13  1879-03-12                   Alfred Abel  176791
# 14  1887-02-03                Giuseppe Becce  216850
# 15  1865-03-20                 Hermann Picha  293176
# 16  1896-02-14                 Hermann Picha  293176
# 17  1898-05-05  Hans Heinrich von Twardowski  286577
# 18  1890-01-16                   Karl Freund  179157
# 19        1881                 Carl Hoffmann  179706
# 20  1912-12-08                Anne Chevalier  950952
# 21  1888-12-27               Thea von Harbou  185667
# 22        1893              Aud Egede-Nissen  303039
# 23        1884            Robert J. Flaherty  174970
# 24  1888-12-28      Friedrich Wilhelm Murnau  176793
# 25  1884-12-05             Fritz Arno Wagner  230769
# 26  1882-07-23                    Hans Kyser  181799
# 27        1885               Axel Graatkjaer  242209
# 28  1872-05-24             Hermann Vallentin  179785
# 29  1893-06-15              Wilhelm Dieterle  219667

# %% [markdown]
# ##### SPARQL #5: Breakdown of carrier types per contributor.

# %%
dataframe = run_query("""
    SELECT DISTINCT ?work ?workLabel ?item ?carrierLabel ?heldLabel
    WHERE
    {
        # ?work wdt:P1 wd:Q1019.
        # ?work wdt:P12 ?manifestation. 
        # ?manifestation wdt:P14 ?item.
        # ?item wdt:P17 ?carrier.
        # ?item wdt:P11 ?held.
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

dataframe = dataframe[['carrierLabel', 'heldLabel', 'work']]
dataframe = dataframe.pivot_table(index=['carrierLabel', 'heldLabel'], aggfunc=lambda x: len(x)).reset_index()
dataframe = dataframe.rename(columns={'work':'item count', 'heldLabel':'contributor', 'carrierLabel':'carrier type'})
line = altair.Chart(dataframe).mark_line(interpolate='linear').encode(x='contributor', y='item count:Q', color='carrier type')
display(altair.layer(line).properties(width=600, height=300))
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ##### SPARQL #6: Breakdown of carrier types per work.

# %%
dataframe = run_query("""
    SELECT DISTINCT ?work ?workLabel ?item ?carrierLabel
    WHERE
    {
        # ?work wdt:P1 wd:Q1019.
        # ?work wdt:P12 ?manifestation. 
        # ?manifestation wdt:P14 ?item.
        # ?item wdt:P17 ?carrier.
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

dataframe = dataframe[['workLabel', 'carrierLabel', 'work']]
dataframe = dataframe.pivot_table(index=['workLabel', 'carrierLabel'], aggfunc=lambda x: len(x)).reset_index()
dataframe = dataframe.rename(columns={'work':'item count', 'workLabel':'work', 'carrierLabel':'carrier type'})
line = altair.Chart(dataframe).mark_line(interpolate='linear').encode(x='work', y='item count:Q', color='carrier type')
display(altair.layer(line).properties(width=600, height=300))
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ##### SPARQL #7: Detail of film base per work.

# %%
dataframe = run_query("""
    SELECT DISTINCT ?work ?workLabel ?item ?carrierLabel ?baseLabel
    WHERE
    {
        # ?work wdt:P1 wd:Q1019.
        # ?work wdt:P12 ?manifestation. 
        # ?manifestation wdt:P14 ?item.
        # ?item wdt:P17 ?carrier.
        # ?item wdt:P20 ?base.
        FILTER ( ?carrier in (wd:Q1006,wd:Q1006) ) 
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

dataframe = dataframe[['workLabel', 'baseLabel', 'work']]
dataframe = dataframe.pivot_table(index=['workLabel', 'baseLabel'], aggfunc=lambda x: len(x)).reset_index()
dataframe = dataframe.rename(columns={'work':'item count', 'workLabel':'work', 'baseLabel':'film base'})
line = altair.Chart(dataframe).mark_line(interpolate='linear').encode(x='work', y='item count:Q', color='film base')
display(altair.layer(line).properties(width=600, height=300))
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ##### SPARQL #8: Nitrate film length per work.

# %%
dataframe = run_query("""
    SELECT DISTINCT ?work ?workLabel ?item ?carrierLabel ?baseLabel ?itemLabel ?metres ?feet
    WHERE
    {
        # ?work wdt:P1 wd:Q1019.
        # ?work wdt:P12 ?manifestation. 
        # ?manifestation wdt:P14 ?item.
        # ?item wdt:P17 ?carrier.
        # ?item wdt:P20 ?base.
        OPTIONAL{?item wdt:P26 ?metres.}
        OPTIONAL{?item wdt:P27 ?feet.}        
        FILTER ( ?carrier in ( wd:Q1006,wd:Q1006 ) ) 
        FILTER ( ?base in ( wd:Q826,wd:Q826 ) ) # this is         
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

def feet_to_metres(row):
    if not row['metres']:
        if row['feet']:
            return float(row['feet'])/3.2808
    else:
        return(row['metres'])

dataframe['metres'] = dataframe.apply(feet_to_metres, axis=1).dropna()
dataframe = dataframe.loc[~dataframe.metres.isin([numpy.nan])]

for x in dataframe.workLabel.unique():
    sample = dataframe.loc[dataframe.workLabel.isin([x])]
    sample = sample.rename(columns={'itemLabel':'items'})
    if len(sample) > 4:
        print(x)        
        line = altair.Chart(sample).mark_bar(interpolate='linear').encode(x='metres:Q', y='items')
        display(altair.layer(line).properties(width=700, height=300).configure_axisY(labelAlign='right'))
# Out:
# Der letzte Mann
# alt.LayerChart(...)
# Faust
# alt.LayerChart(...)
# Tabu
# alt.LayerChart(...)

# %% [markdown]
# ##### SPARQL #9: Linking Wikibase to Wikidata.

# %%
dataframe1 = run_query("""
    SELECT ?work ?workLabel ?wikidata ?sfi
    WHERE
    {
        # ?work wdt:P1 wd:Q1019;
        p:P29 [ps:P29 ?wikidata;  pq:P33 wd:Q1027 ];
        p:P29 [ps:P29 ?sfi;  pq:P33 wd:Q15 ]        
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
    }
    """, 'http://167.99.135.149:8989/bigdata/sparql')

dataframe2 = run_query("""
    SELECT ?wikidata ?director ?imdb
    WHERE 
    {
        # ?wikidata wdt:P31 wd:Q11424.
        # ?wikidata wdt:P57 ?director.
        # ?wikidata wdt:P345 ?imdb.
        FILTER ( ?director in ( wd:Q55412,wd:Q55412 ) ) 
    }
    """, 'https://query.wikidata.org/sparql')

dataframe2['wikidata'] = dataframe2['wikidata'].str.split('/').str[-1]
dataframe3 = pandas.merge(dataframe1, dataframe2, on='wikidata', how='inner')

print(len(dataframe3))
dataframe3.head()
# Out:
# 6
#    wikidata                             work                      workLabel  \
# 0  Q1797606  http://wikibase.svc/entity/Q124                       4 Devils
# 1   Q601283   http://wikibase.svc/entity/Q55  Der BUCKLIGE UND DIE TÄNZERIN
# 2   Q672480  http://wikibase.svc/entity/Q215                          Faust
# 3   Q587579  http://wikibase.svc/entity/Q100                           Tabu
# 4  Q3793222  http://wikibase.svc/entity/Q378          Der Gang in die Nacht
#
#       sfi                               director       imdb
# 0   26009  http://www.wikidata.org/entity/Q55412  tt0018907
# 1  625469  http://www.wikidata.org/entity/Q55412  tt0011031
# 2    9190  http://www.wikidata.org/entity/Q55412  tt0016847
# 3   31600  http://www.wikidata.org/entity/Q55412  tt0022458
# 4   91955  http://www.wikidata.org/entity/Q55412  tt0011217
